# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunticha24/data_viz_2022/blob/main/Project_Dinosaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Present Project กลุ่ม

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Project_Dinosaur'

# %% [markdown]
# ##ตารางข้อมูล covid ปี2020
#
# * No รหัสผู้ป่วย
# * Age อายุของผู้ป่วย
# * Sex เพศผู้ป่วย
# * Nationality สัญชาติ
# * Province of isolation จังหวัดที่รักษาตัว
# * Notification Date วันที่กระทรวงได้รับรายงาน
# * Announce Date วันที่แถลงข่าว
# * Province of onset จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย
# * risk สถานที่

# %%
data_covid2020 =  pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_covid2020
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(1)

# %%
data_covid2021_1 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv'))
data_covid2021_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(2)

# %%
data_covid2021_2 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv'))
data_covid2021_2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ##ตารางข้อมูล covid ปี2022

# %%
data_covid2022 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv'))
data_covid2022
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ##ต่อตาราง

# %%
Covid = pd.concat([data_covid2020,data_covid2021_1,data_covid2021_2,data_covid2022])
Covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3325951 rows x 12 columns]

# %% [markdown]
# ###ตรวจสอบค่า Missing

# %%
Covid.isnull()
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 433548  False          False          False  False   True   True         True
# 433549  False          False          False  False   True   True         True
# 433550  False          False          False  False   True   True         True
# 433551  False          False          False  False   True   True         True
# 433552  False          False          False  False   True   True         True
#
#         province_of_isolation   risk  province_of_onset  district_of_onset  \
# 0                       False  False              False               True
# 1                       False  False              False               True
# 2                       False  False              False              False
# 3                       False  False              False               True
# 4                       False  False              False               True
# ...                       ...    ...                ...                ...
# 433548                  False  False               True               True
# 433549                  False  False               True               True
# 433550                  False  False               True               True
# 433551                  False  False               True               True
# 433552                  False  False               True               True
#
#         Unnamed: 11
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 433548         True
# 433549         True
# 433550         True
# 433551         True
# 433552         True
#
# [3325951 rows x 12 columns]

# %%
Covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# ###แทนค่า mising

# %%
Covid = Covid.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่ระบุ','age':'ไม่ระบุ','Unit':'ปี','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})

# %%
Covid
# Out:
#             No. announce_date Notified date   sex      age Unit  nationality  \
# 0             1     12/1/2020   ไม่มีข้อมูล  หญิง     61.0   ปี        China
# 1             2     17/1/2020   ไม่มีข้อมูล  หญิง     74.0   ปี        China
# 2             3     22/1/2020   ไม่มีข้อมูล  หญิง     73.0   ปี     Thailand
# 3             4     22/1/2020   ไม่มีข้อมูล   ชาย     68.0   ปี        China
# 4             5     24/1/2020   ไม่มีข้อมูล  หญิง     66.0   ปี        China
# ...         ...           ...           ...   ...      ...  ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล          NaN
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล          NaN
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล          NaN
# ...                  ...               ...          ...
# 433548       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 433549       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 433550       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 433551       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
# 433552       ไม่มีข้อมูล       ไม่มีข้อมูล          NaN
#
# [3325951 rows x 12 columns]

# %%
Covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11               True
# dtype: bool

# %%
Covid.drop(['Unnamed: 11'], axis=1, inplace=True)
Covid
# Out:
#             No. announce_date Notified date   sex      age Unit  nationality  \
# 0             1     12/1/2020   ไม่มีข้อมูล  หญิง     61.0   ปี        China
# 1             2     17/1/2020   ไม่มีข้อมูล  หญิง     74.0   ปี        China
# 2             3     22/1/2020   ไม่มีข้อมูล  หญิง     73.0   ปี     Thailand
# 3             4     22/1/2020   ไม่มีข้อมูล   ชาย     68.0   ปี        China
# 4             5     24/1/2020   ไม่มีข้อมูล  หญิง     66.0   ปี        China
# ...         ...           ...           ...   ...      ...  ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  ไม่ระบุ   ปี  ไม่มีข้อมูล
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร       ไม่มีข้อมูล
# 1          กรุงเทพมหานคร       ไม่มีข้อมูล
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร       ไม่มีข้อมูล
# 4          กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                  ...               ...
# 433548       ไม่มีข้อมูล       ไม่มีข้อมูล
# 433549       ไม่มีข้อมูล       ไม่มีข้อมูล
# 433550       ไม่มีข้อมูล       ไม่มีข้อมูล
# 433551       ไม่มีข้อมูล       ไม่มีข้อมูล
# 433552       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [3325951 rows x 11 columns]

# %%
Covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่าข้อมูลไม่มีค่า missing แล้ว

# %% [markdown]
# ##ข้อมูลจังหวัดแต่ละภูมิภาค

# %%
import pandas as pd

# %%
region = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
}

# %%
region_df = pd.DataFrame.from_dict(region) #คำสั่งสร้างตาราง Dataframe
region_df
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ##ปริมาณการเดินทางบนทางหลวงปีพ.ศ.2563 - พ.ศ.2564

# %%
highway =  pd.read_csv(os.path.join(path,'highway.csv'))
highway
# Out:
#         ปี  หมายเลขทางหลวง  หมายเลขตอนควบคุม  \
# 0     2563               1               101
# 1     2563               1               102
# 2     2563               1               201
# 3     2563               1               202
# 4     2563               1               300
# ...    ...             ...               ...
# 5377  2564            4369               100
# 5378  2564            4370               100
# 5379  2564            4371               100
# 5380  2564            4372               100
# 5381  2564            4373               100
#
#                                      ชื่อตอน  รถยนต์นั่งไม่เกิน 7 คน  \
# 0              อนุสาวรีย์หลักสี่ - สะพานใหม่                 6249384
# 1              แยก คปอ. - สนามกีฬาธูปะเตมีย์                20900718
# 2     สนามกีฬาธูปะเตมีย์ - ต่างระดับคลองหลวง               740924709
# 3      ต่างระดับคลองหลวง - ประตูน้ำพระอินทร์               415404858
# 4                 ประตูน้ำพระอินทร์ - หนองแค               350458648
# ...                                      ...                     ...
# 5377    พรุเตียว - ด่านศุลกากรสะเดาแห่งที่ 2                  284858
# 5378                      ทางเข้าปากบางสะกอม                  157654
# 5379                       สามแยก - หยงสตาร์                10758415
# 5380                           ทางเข้าวังยาว                  216810
# 5381                     หนองหิน – ด่านสิงขร                 7583252
#
#       รถยนต์นั่งเกิน  7 คน  รถโดยสารขนาดเล็ก  รถโดยสารขนาดกลาง  \
# 0                  2450282            145854            228308
# 1                  8194830            487801            763562
# 2                172610044          85107915          20080902
# 3                178351520          17360203          29404721
# 4                208314859          82341810          21061646
# ...                    ...               ...               ...
# 5377                212640                 0             10030
# 5378                 81486                 0                 0
# 5379              13122650             65401            143882
# 5380                260533              5420              1084
# 5381                737328            468765            102542
#
#       รถโดยสารขนาดใหญ่  รถบรรทุกขนาดเล็ก  รถบรรทุกขนาดกลาง  รถบรรทุกขนาดใหญ่  \
# 0               415881           2211134            235535             58145
# 1              1390891           7395013            787732            194461
# 2             56789434         287132586          43042278          19009481
# 3             49137329         253823949          84643858          16064037
# 4             33125217         169515001         160725261         107252688
# ...                ...               ...               ...               ...
# 5377                 0            692084              2006                 0
# 5378                 0            401255             16469             11665
# 5379                 0           9747974            945040            598416
# 5380              1807            113645             17345              9214
# 5381             24415          10596045            410169            395521
#
#       รถบรรทุกพ่วง  รถบรรทุกกึ่งพ่วง         รวม  รถจักรยานยนต์  \
# 0            19053             30879    12044455        3100055
# 1            63722            103273    40282003       10367960
# 2          5563148           4133213  1434393710       78102470
# 3         11562550           7421370  1063174395       64237430
# 4        106330063          95585945  1334711138       15317561
# ...            ...               ...         ...            ...
# 5377             0                 0     1201618        2172541
# 5378          3774               515      672818         265903
# 5379        153692             55591    35591061       12498074
# 5380             0                 0      625858         295946
# 5381        141606            107425    20567068       10766949
#
#               จังหวัด
# 0       กรุงเทพมหานคร
# 1       กรุงเทพมหานคร
# 2            ปทุมธานี
# 3            ปทุมธานี
# 4     พระนครศรีอยุธยา
# ...               ...
# 5377            สงขลา
# 5378            สงขลา
# 5379             ตรัง
# 5380  ประจวบคีรีขันธ์
# 5381  ประจวบคีรีขันธ์
#
# [5382 rows x 17 columns]

# %%
highway.isnull().any()
# Out:
# ปี                        False
# หมายเลขทางหลวง            False
# หมายเลขตอนควบคุม          False
# ชื่อตอน                   False
# รถยนต์นั่งไม่เกิน 7 คน    False
# รถยนต์นั่งเกิน  7 คน      False
# รถโดยสารขนาดเล็ก          False
# รถโดยสารขนาดกลาง          False
# รถโดยสารขนาดใหญ่          False
# รถบรรทุกขนาดเล็ก          False
# รถบรรทุกขนาดกลาง          False
# รถบรรทุกขนาดใหญ่          False
# รถบรรทุกพ่วง              False
# รถบรรทุกกึ่งพ่วง          False
# รวม                       False
# รถจักรยานยนต์             False
# จังหวัด                   False
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่าข้อมูลไม่มีค่า missing

# %% [markdown]
# ##Covid + region

# %%
Covid_re = Covid.merge(region_df,how='right',left_on='province_of_isolation',right_on = 'จังหวัด') 
Covid_re
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0            973     26/3/2020     25/3/2020   ชาย  48.0   ปี    Thailand
# 1           1864      2/4/2020      1/4/2020  หญิง  46.0   ปี    Thailand
# 2           6493    30/12/2020    29/12/2020  หญิง  37.0   ปี    Thailand
# 3           7390      3/1/2021      2/1/2021  หญิง  26.0   ปี        Laos
# 4          31038     10/4/2021      9/4/2021   ชาย  38.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 3319366  3297753     18/3/2022     17/3/2022  หญิง  36.0   ปี    Thailand
# 3319367  3297754     18/3/2022     17/3/2022  หญิง  26.0   ปี    Thailand
# 3319368  3297755     18/3/2022     17/3/2022  หญิง  11.0   ปี    Thailand
# 3319369  3297756     18/3/2022     17/3/2022  หญิง  16.0   ปี    Thailand
# 3319370  3297757     18/3/2022     17/3/2022  หญิง  27.0   ปี    Thailand
#
#         province_of_isolation                                           risk  \
# 0                  อำนาจเจริญ                                    สถานบันเทิง
# 1                  อำนาจเจริญ                  คนไทยเดินทางกลับจากต่างประเทศ
# 2                  อำนาจเจริญ                                  Cluster ระยอง
# 3                  อำนาจเจริญ    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                  อำนาจเจริญ  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# ...                       ...                                            ...
# 3319366                  ตรัง                บุคลากรด้านการแพทย์และสาธารณสุข
# 3319367                  ตรัง                                          อื่นๆ
# 3319368                  ตรัง                                          อื่นๆ
# 3319369                  ตรัง                                          อื่นๆ
# 3319370                  ตรัง                                          อื่นๆ
#
#         province_of_onset district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0              อำนาจเจริญ             เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1              อำนาจเจริญ       ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2              อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3              อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4              อำนาจเจริญ             เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                   ...               ...         ...                    ...
# 3319366       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง                    ใต้
# 3319367       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง                    ใต้
# 3319368       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง                    ใต้
# 3319369       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง                    ใต้
# 3319370       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง                    ใต้
#
# [3319371 rows x 13 columns]

# %%
Covid_re.isnull().any()
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality               False
# province_of_isolation     False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่าข้อมูลไม่มีค่า missing

# %% [markdown]
# ##เลือกมาเฉพาะ column ที่ต้องการ

# %%
Covid_re_table = Covid_re[['province_of_isolation','province_of_onset','district_of_onset','จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)']]
Covid_re_table
# Out:
#         province_of_isolation province_of_onset district_of_onset     จังหวัด  \
# 0                  อำนาจเจริญ        อำนาจเจริญ             เมือง  อำนาจเจริญ
# 1                  อำนาจเจริญ        อำนาจเจริญ       ปทุมราชวงศา  อำนาจเจริญ
# 2                  อำนาจเจริญ        อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ
# 3                  อำนาจเจริญ        อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ
# 4                  อำนาจเจริญ        อำนาจเจริญ             เมือง  อำนาจเจริญ
# ...                       ...               ...               ...         ...
# 3319366                  ตรัง       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง
# 3319367                  ตรัง       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง
# 3319368                  ตรัง       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง
# 3319369                  ตรัง       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง
# 3319370                  ตรัง       ไม่มีข้อมูล       ไม่มีข้อมูล        ตรัง
#
#         6 ภูมิภาค (ภูมิศาสตร์)
# 0           ตะวันออกเฉียงเหนือ
# 1           ตะวันออกเฉียงเหนือ
# 2           ตะวันออกเฉียงเหนือ
# 3           ตะวันออกเฉียงเหนือ
# 4           ตะวันออกเฉียงเหนือ
# ...                        ...
# 3319366                    ใต้
# 3319367                    ใต้
# 3319368                    ใต้
# 3319369                    ใต้
# 3319370                    ใต้
#
# [3319371 rows x 5 columns]

# %%
Covid_re_table.isnull().any()
# Out:
# province_of_isolation     False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่าข้อมูลไม่มีค่า missing

# %% [markdown]
# ##Covid_re_table + highway

# %%
Covid_re_ta_high = Covid_re_table.merge(highway,how='right',left_on='province_of_isolation',right_on = 'จังหวัด')
Covid_re_ta_high
