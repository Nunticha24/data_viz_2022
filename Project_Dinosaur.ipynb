# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunticha24/data_viz_2022/blob/main/Project_Dinosaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Present Project กลุ่ม
#
# https://drive.google.com/drive/u/0/folders/1G9XaOQ1IExr0m-UwWypqGPtGzi5HE-YL

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Project_Dinosaur'

# %% [markdown]
# ##ตารางข้อมูล covid ปี2020
#
# * No รหัสผู้ป่วย
# * Age อายุของผู้ป่วย
# * Sex เพศผู้ป่วย
# * Nationality สัญชาติ
# * Province of isolation จังหวัดที่รักษาตัว
# * Notification Date วันที่กระทรวงได้รับรายงาน
# * Announce Date วันที่แถลงข่าว
# * Province of onset จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย
# * risk สถานที่

# %%
data_covid2020 =  pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_covid2020
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(1)

# %%
data_covid2021_1 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv'))
data_covid2021_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(2)

# %%
data_covid2021_2 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv'))
data_covid2021_2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2022

# %%
data_covid2022 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv'))
data_covid2022
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ##ต่อตาราง

# %%
covid = pd.concat([data_covid2020,data_covid2021_1,data_covid2021_2,data_covid2022])
covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ###เลือกเอา column ที่ต้องการ

# %%
Covid = covid[['No.','announce_date','sex','age','Unit','province_of_isolation']]
Covid
# Out:
#             No. announce_date   sex   age Unit province_of_isolation
# 0             1     12/1/2020  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี                นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี               นนทบุรี
# ...         ...           ...   ...   ...  ...                   ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง   NaN  NaN         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง   NaN  NaN         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง   NaN  NaN                 สงขลา
# 433552  3303169     18/3/2022  หญิง   NaN  NaN                 สงขลา
#
# [3325951 rows x 6 columns]

# %% [markdown]
# ###ตรวจสอบค่า Missing

# %%
Covid.isnull().any()
# Out:
# No.                      False
# announce_date            False
# sex                       True
# age                       True
# Unit                      True
# province_of_isolation     True
# dtype: bool

# %% [markdown]
# ###แทนค่า mising

# %%
Covid[['sex']] = Covid[['sex']].fillna('ไม่ระบุ')
Covid[['Unit']] = Covid[['Unit']].fillna('ปี')
Covid[['province_of_isolation']] = Covid[['province_of_isolation']].fillna('ไม่ระบุ')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
Covid = Covid.fillna(method="bfill") #ใช้ bfill คือการแทนที่ด้วยค่าถัดไปคือการนำค่าถัดไปที่มีค่า ของเซลล์ตัวเองมาแทนที่ลงในช่องที่เป็น NaN
Covid.isnull().any() #เช็คข้อมูลในแต่ละคอลัมน์อีกครั้ง
# Out:
# No.                      False
# announce_date            False
# sex                      False
# age                       True
# Unit                     False
# province_of_isolation    False
# dtype: bool

# %%
Covid
# Out:
#             No. announce_date   sex   age Unit province_of_isolation
# 0             1     12/1/2020  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี                นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี               นนทบุรี
# ...         ...           ...   ...   ...  ...                   ...
# 433548  3303165     18/3/2022  หญิง   NaN   ปี         กรุงเทพมหานคร
# 433549  3303166     18/3/2022  หญิง   NaN   ปี         กรุงเทพมหานคร
# 433550  3303167     18/3/2022  หญิง   NaN   ปี         กรุงเทพมหานคร
# 433551  3303168     18/3/2022  หญิง   NaN   ปี                 สงขลา
# 433552  3303169     18/3/2022  หญิง   NaN   ปี                 สงขลา
#
# [3325951 rows x 6 columns]

# %%
set(Covid['province_of_isolation'])
# Out:
# {'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
# ...

# %%
#ทำข้อมูลให้เหมือนกัน
Covid['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น', 'ภููเก็ต':'ภูเก็ต'}, inplace=True)

# %%
len(set(Covid['province_of_isolation']))
# Out:
# 78

# %%
Covid_gb = Covid.groupby('province_of_isolation').size().reset_index(name='จำนวนผู้รักษาตัวสะสม')  #สร้างตารางที่รวมจำนวนผู้รักษาตัวในแต่ละจังหวัด
Covid_gb
# Out:
#    province_of_isolation  จำนวนผู้ติดเชื้อ
# 0                 กระบี่             19856
# 1          กรุงเทพมหานคร            630082
# 2              กาญจนบุรี             36985
# 3              กาฬสินธุ์             20821
# 4              กำแพงเพชร             15724
# ..                   ...               ...
# 73             เพชรบูรณ์             19482
# 74                   เลย             10762
# 75                  แพร่              5930
# 76            แม่ฮ่องสอน              4475
# 77               ไม่ระบุ              3956
#
# [78 rows x 2 columns]

# %%
datacovid_dropped = Covid.dropna() #drop ค่าว่างออกจากตาราง
datacovid_dropped
# Out:
#             No. announce_date      sex   age Unit province_of_isolation
# 0             1     12/1/2020     หญิง  61.0   ปี         กรุงเทพมหานคร
# 1             2     17/1/2020     หญิง  74.0   ปี         กรุงเทพมหานคร
# 2             3     22/1/2020     หญิง  73.0   ปี                นครปฐม
# 3             4     22/1/2020      ชาย  68.0   ปี         กรุงเทพมหานคร
# 4             5     24/1/2020     หญิง  66.0   ปี               นนทบุรี
# ...         ...           ...      ...   ...  ...                   ...
# 433445  3303062     18/3/2022  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 433446  3303063     18/3/2022  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 433447  3303064     18/3/2022  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 433448  3303065     18/3/2022  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 433449  3303066     18/3/2022  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
# [3325848 rows x 6 columns]

# %% [markdown]
# ##ภูมิภาค แบ่งเป็น 6 ภูมิภาค (ภูมิศาสตร์)

# %%
data_region = {'Province': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']
}
data_region = pd.DataFrame.from_dict(data_region) 
data_region #แสดงตาราง Region
# Out:
#       Province 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ##นำเข้าข้อมูลที่เลือกเอง

# %% [markdown]
# ##การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19

# %%
passenger =  pd.read_csv(os.path.join(path,'passenger-covid19.csv'))
passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0     1/1/2020   1,483,255     885,353     272,578        102,678
# 1     2/1/2020   1,705,026   1,269,207     291,990        104,613
# 2     3/1/2020   1,752,572   1,366,412     301,260        100,575
# 3     4/1/2020   1,576,146   1,027,281     271,171        100,852
# 4     5/1/2020   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805  16/3/2022     641,639     685,639      81,496         50,761
# 806  17/3/2022     657,339     676,376      93,516         53,177
# 807  18/3/2022     646,203     729,250     104,801         63,230
# 808  19/3/2022     555,727     580,102      93,046         58,347
# 809  20/3/2022     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน) รถส่วนบุคคล เข้า - ออก กทม. (คัน)  \
# 0                2,743,864                         2,310,406
# ...

# %%
passenger.isnull().any()
# Out:
# วันที่                                                          False
# ทางถนน (คน)                                                     False
# ทางราง (คน)                                                     False
# ทางน้ำ (คน)                                                     False
# ทางอากาศ* (คน)                                                  False
# รวมประชาชนเดินทาง (คน)                                          False
# รถส่วนบุคคล เข้า - ออก กทม. (คัน)                               False
# รถโดยสารประจำทางใน กทม. และปริมณฑล (ขสมก. และ รถร่วม) (คน)      False
# รถโดยสารประจำทางระหว่าง กทม. - ตจว. \n(บขส. และ รถร่วม) (คน)    False
# รถส่วนบุคคล เข้า - ออก กทม. (คัน).1                             False
# บนถนนทางหลวง                                                    False
# บนทางด่วน                                                       False
# รวมรถไฟฟ้า                                                      False
# ...

# %% [markdown]
# ###เลือกเอา column ที่ต้องการ

# %%
Passenger = passenger[['วันที่','ทางถนน (คน)','ทางราง (คน)','ทางน้ำ (คน)', 'ทางอากาศ* (คน)', 'รวมประชาชนเดินทาง (คน)']]
Passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0     1/1/2020   1,483,255     885,353     272,578        102,678
# 1     2/1/2020   1,705,026   1,269,207     291,990        104,613
# 2     3/1/2020   1,752,572   1,366,412     301,260        100,575
# 3     4/1/2020   1,576,146   1,027,281     271,171        100,852
# 4     5/1/2020   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805  16/3/2022     641,639     685,639      81,496         50,761
# 806  17/3/2022     657,339     676,376      93,516         53,177
# 807  18/3/2022     646,203     729,250     104,801         63,230
# 808  19/3/2022     555,727     580,102      93,046         58,347
# 809  20/3/2022     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน)
# 0                2,743,864
# 1                3,370,836
# 2                3,520,819
# 3                2,975,450
# 4                2,835,519
# ...

# %% [markdown]
# ###ตรวจสอบค่า Missing

# %%
Passenger.isnull().any()
# Out:
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ##รวมข้อมูล Covid กับ ภูมิภาค

# %%
covid_re = datacovid_dropped.merge(data_region,how='left',left_on='province_of_isolation',right_on = 'Province') 
covid_re
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 0              1     12/1/2020     หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2     17/1/2020     หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3     22/1/2020     หญิง  73.0   ปี                นครปฐม
# 3              4     22/1/2020      ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5     24/1/2020     หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...      ...   ...  ...                   ...
# 3325843  3303062     18/3/2022  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 3325844  3303063     18/3/2022  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 3325845  3303064     18/3/2022  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 3325846  3303065     18/3/2022  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 3325847  3303066     18/3/2022  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)
# ...

# %% [markdown]
# ###ตรวจสอบค่า Missing

# %%
covid_re.isnull().any()
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# Unit                      False
# province_of_isolation     False
# Province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# dtype: bool

# %%
covid_re = covid_re.fillna(value={'จังหวัด':'ไม่ระบุ','6 ภูมิภาค (ภูมิศาสตร์)':'ไม่ระบุ'})
covid_re
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 0              1     12/1/2020     หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2     17/1/2020     หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3     22/1/2020     หญิง  73.0   ปี                นครปฐม
# 3              4     22/1/2020      ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5     24/1/2020     หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...      ...   ...  ...                   ...
# 3325843  3303062     18/3/2022  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 3325844  3303063     18/3/2022  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 3325845  3303064     18/3/2022  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 3325846  3303065     18/3/2022  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 3325847  3303066     18/3/2022  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)
# ...

# %% [markdown]
# ##นำข้อมูล Covid กับ ภูมิภาค ไปรวมกับ การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19

# %%
covid_re_pass = covid_re.merge(Passenger,how='left',left_on='announce_date',right_on = 'วันที่') 
covid_re_pass
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 0              1     12/1/2020     หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2     17/1/2020     หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3     22/1/2020     หญิง  73.0   ปี                นครปฐม
# 3              4     22/1/2020      ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5     24/1/2020     หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...      ...   ...  ...                   ...
# 3325843  3303062     18/3/2022  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 3325844  3303063     18/3/2022  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 3325845  3303064     18/3/2022  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 3325846  3303065     18/3/2022  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 3325847  3303066     18/3/2022  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %%
covid_re_pass.isnull().any()
# Out:
# No.                       False
# announce_date             False
# sex                       False
# age                       False
# Unit                      False
# province_of_isolation     False
# Province                   True
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ##เพิ่มคอลัมน์ month & years

# %%
covid_re_pass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3325848 entries, 0 to 3325847
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   No.                     int64
#  1   announce_date           object
#  2   sex                     object
#  3   age                     object
#  4   Unit                    object
#  5   province_of_isolation   object
#  6   Province                object
#  7   6 ภูมิภาค (ภูมิศาสตร์)  object
#  8   วันที่                  object
#  9   ทางถนน (คน)             object
#  10  ทางราง (คน)             object
#  11  ทางน้ำ (คน)             object
#  12  ทางอากาศ* (คน)          object
#  13  รวมประชาชนเดินทาง (คน)  object
# dtypes: int64(1), object(13)
# memory usage: 380.6+ MB

# %%
import datetime

# %%
data = pd.DataFrame(covid_re_pass)
data['announce_date'] = pd.to_datetime(data['announce_date'], format = "%d/%m/%Y")
data['year'] = data['announce_date'].dt.year
data['month'] = data['announce_date'].dt.month

# %%
data
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 0              1    2020-01-12     หญิง  61.0   ปี         กรุงเทพมหานคร
# 1              2    2020-01-17     หญิง  74.0   ปี         กรุงเทพมหานคร
# 2              3    2020-01-22     หญิง  73.0   ปี                นครปฐม
# 3              4    2020-01-22      ชาย  68.0   ปี         กรุงเทพมหานคร
# 4              5    2020-01-24     หญิง  66.0   ปี               นนทบุรี
# ...          ...           ...      ...   ...  ...                   ...
# 3325843  3303062    2022-03-18  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 3325844  3303063    2022-03-18  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 3325845  3303064    2022-03-18  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 3325846  3303065    2022-03-18  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 3325847  3303066    2022-03-18  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %% [markdown]
# ##แบ่งข้อมูลตามปี

# %%
data2020 = data[(data['year'] == 2020)]
data2020
# Out:
#        No. announce_date   sex   age Unit province_of_isolation  \
# 0        1    2020-01-12  หญิง  61.0   ปี         กรุงเทพมหานคร
# 1        2    2020-01-17  หญิง  74.0   ปี         กรุงเทพมหานคร
# 2        3    2020-01-22  หญิง  73.0   ปี                นครปฐม
# 3        4    2020-01-22   ชาย  68.0   ปี         กรุงเทพมหานคร
# 4        5    2020-01-24  หญิง  66.0   ปี               นนทบุรี
# ...    ...           ...   ...   ...  ...                   ...
# 6880  6881    2020-12-31  หญิง  39.0   ปี                 ระยอง
# 6881  6882    2020-12-31   ชาย  54.0   ปี                 ระยอง
# 6882  6883    2020-12-31   ชาย  54.0   ปี                 ระยอง
# 6883  6884    2020-12-31   ชาย  56.0   ปี                 ระยอง
# 6884  6885    2020-12-31   ชาย  70.0   ปี                 ระยอง
#
#            Province 6 ภูมิภาค (ภูมิศาสตร์)      วันที่ ทางถนน (คน)  \
# 0     กรุงเทพมหานคร                   กลาง   12/1/2020   1,511,236
# ...

# %%
data2021_1 = data[((data['month'] == 1) |(data['month'] == 2) | (data['month'] == 3)) & (data['year'] == 2021)]
data2021_1
# Out:
#          No. announce_date   sex   age Unit province_of_isolation  \
# 124      125    2021-03-06  หญิง  55.0   ปี              ปทุมธานี
# 6885    6886    2021-01-01  หญิง  40.0   ปี         กรุงเทพมหานคร
# 6886    6887    2021-01-01  หญิง  21.0   ปี              ปทุมธานี
# 6887    6888    2021-01-01  หญิง  20.0   ปี                นครปฐม
# 6888    6889    2021-01-01  หญิง  47.0   ปี             สมุทรสาคร
# ...      ...           ...   ...   ...  ...                   ...
# 28858  28859    2021-03-31   ชาย  35.0   ปี         กรุงเทพมหานคร
# 28859  28860    2021-03-31   ชาย  63.0   ปี         กรุงเทพมหานคร
# 28860  28861    2021-03-31  หญิง  34.0   ปี                   ตาก
# 28861  28862    2021-03-31  หญิง  22.0   ปี                   ตาก
# 28862  28863    2021-03-31   ชาย  17.0   ปี              นราธิวาส
#
#             Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# 124         ปทุมธานี                   กลาง   6/3/2021     862,101
# ...

# %%
data2021_2 = data[((data['month'] == 4) |(data['month'] == 5) | (data['month'] == 6)) & (data['year'] == 2021)]
data2021_2
# Out:
#            No. announce_date   sex   age Unit province_of_isolation  \
# 28863    28864    2021-04-01   ชาย  27.0   ปี             สมุทรสาคร
# 28864    28865    2021-04-01  หญิง  18.0   ปี             สมุทรสาคร
# 28865    28866    2021-04-01   ชาย  28.0   ปี             สมุทรสาคร
# 28866    28867    2021-04-01  หญิง  30.0   ปี             สมุทรสาคร
# 28867    28868    2021-04-01  หญิง  30.0   ปี             สมุทรสาคร
# ...        ...           ...   ...   ...  ...                   ...
# 259296  259297    2021-06-30  หญิง  62.0   ปี                 สงขลา
# 259297  259298    2021-06-30  หญิง  63.0   ปี                 สงขลา
# 259298  259299    2021-06-30  หญิง  34.0   ปี                 สงขลา
# 259299  259300    2021-06-30  หญิง  45.0   ปี                 สงขลา
# 259300  259301    2021-06-30   ชาย  37.0   ปี                 สงขลา
#
#          Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน) ทางราง (คน)  \
# ...

# %%
data2021_3 = data[((data['month'] == 7)) & (data['year'] == 2021)]
data2021_3
# Out:
#            No. announce_date   sex   age Unit province_of_isolation  \
# 259301  259302    2021-07-01   ชาย  35.0   ปี              เชียงราย
# 259302  259303    2021-07-01  หญิง  41.0   ปี              เชียงราย
# 259303  259304    2021-07-01  หญิง  58.0   ปี              เชียงราย
# 259304  259305    2021-07-01   ชาย  37.0   ปี              เชียงราย
# 259305  259306    2021-07-01   ชาย  37.0   ปี              เชียงราย
# ...        ...           ...   ...   ...  ...                   ...
# 597282  597283    2021-07-31  หญิง  24.0   ปี         กรุงเทพมหานคร
# 597283  597284    2021-07-31  หญิง  35.0   ปี         กรุงเทพมหานคร
# 597284  597285    2021-07-31  หญิง  41.0   ปี         กรุงเทพมหานคร
# 597285  597286    2021-07-31  หญิง  34.0   ปี         กรุงเทพมหานคร
# 597286  597287    2021-07-31   ชาย  41.0   ปี         กรุงเทพมหานคร
#
#              Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# 259301       เชียงราย                  เหนือ   1/7/2021     574,401
# ...

# %%
data2021_4 = data[((data['month'] == 8)) & (data['year'] == 2021)]
data2021_4
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 597287    597288    2021-08-01      ชาย  53.0   ปี             เชียงใหม่
# 597288    597289    2021-08-01     หญิง  30.0   ปี             เชียงใหม่
# 597289    597290    2021-08-01     หญิง  20.0   ปี             เชียงใหม่
# 597290    597291    2021-08-01      ชาย  50.0   ปี             เชียงใหม่
# 597291    597292    2021-08-01      ชาย  29.0   ปี             เชียงใหม่
# ...          ...           ...      ...   ...  ...                   ...
# 1227506  1204725    2021-08-31      ชาย  31.0   ปี             กาญจนบุรี
# 1227507  1204726    2021-08-31      ชาย  33.0   ปี             กาญจนบุรี
# 1227508  1204727    2021-08-31      ชาย  59.0   ปี            สุพรรณบุรี
# 1227509  1204728    2021-08-31      ชาย  36.0   ปี            นครราชสีมา
# 1227510  1204729    2021-08-31  ไม่ระบุ  49.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %%
data2021_5 = data[((data['month'] == 9)) & (data['year'] == 2021)]
data2021_5
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 1227511  1204730    2021-09-01     หญิง  49.0   ปี             เชียงใหม่
# 1227512  1204731    2021-09-01      ชาย  29.0   ปี             เชียงใหม่
# 1227513  1204732    2021-09-01     หญิง  16.0   ปี             เชียงใหม่
# 1227514  1204733    2021-09-01     หญิง   1.0   ปี             เชียงใหม่
# 1227515  1204734    2021-09-01     หญิง  30.0   ปี             เชียงใหม่
# ...          ...           ...      ...   ...  ...                   ...
# 1626252  1603471    2021-09-30      ชาย  34.0   ปี              เพชรบุรี
# 1626253  1603472    2021-09-30  ไม่ระบุ  40.0   ปี                  ตรัง
# 1626254  1603473    2021-09-30      ชาย  40.0   ปี                  ตรัง
# 1626255  1603474    2021-09-30      ชาย  40.0   ปี          สุราษฎร์ธานี
# 1626256  1603475    2021-09-30      ชาย  30.0   ปี                 สงขลา
#
#              Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %%
data2021_6 = data[((data['month'] == 10) |(data['month'] == 11) | (data['month'] == 12)) & (data['year'] == 2021)]
data2021_6
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 1626257  1603476    2021-10-01  หญิง  30.0   ปี                 พะเยา
# 1626258  1603477    2021-10-01  หญิง  32.0   ปี                 พะเยา
# 1626259  1603478    2021-10-01  หญิง  38.0   ปี              เชียงราย
# 1626260  1603479    2021-10-01   ชาย  41.0   ปี              เชียงราย
# 1626261  1603480    2021-10-01   ชาย  31.0   ปี              เชียงราย
# ...          ...           ...   ...   ...  ...                   ...
# 2246212  2223431    2021-12-31  หญิง  39.0   ปี                 ระนอง
# 2246213  2223432    2021-12-31   ชาย  39.0   ปี                  สตูล
# 2246214  2223433    2021-12-31   ชาย  39.0   ปี              ปทุมธานี
# 2246215  2223434    2021-12-31   ชาย  39.0   ปี         กรุงเทพมหานคร
# 2246216  2223435    2021-12-31   ชาย  39.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)      วันที่ ทางถนน (คน)  \
# ...

# %%
data2022_1 = data[((data['month'] == 1)) & (data['year'] == 2022)]
data2022_1
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 2246217  2223436    2022-01-01   ชาย  39.0   ปี                 พะเยา
# 2246218  2223437    2022-01-01  หญิง  39.0   ปี                 พะเยา
# 2246219  2223438    2022-01-01   ชาย  64.0   ปี                 พะเยา
# 2246220  2223439    2022-01-01   ชาย  27.0   ปี                 พะเยา
# 2246221  2223440    2022-01-01  หญิง  35.0   ปี                 พะเยา
# ...          ...           ...   ...   ...  ...                   ...
# 2463319  2440538    2022-01-31   ชาย  35.0   ปี               ขอนแก่น
# 2463320  2440539    2022-01-31   ชาย  35.0   ปี         กรุงเทพมหานคร
# 2463321  2440540    2022-01-31   ชาย  35.0   ปี         กรุงเทพมหานคร
# 2463322  2440541    2022-01-31   ชาย  35.0   ปี         กรุงเทพมหานคร
# 2463323  2440542    2022-01-31   ชาย  35.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %%
data2022_2 = data[((data['month'] == 2)) & (data['year'] == 2022)]
data2022_2
# Out:
#              No. announce_date   sex   age Unit province_of_isolation  \
# 2463324  2440543    2022-02-01  หญิง  35.0   ปี                 พะเยา
# 2463325  2440544    2022-02-01  หญิง  19.0   ปี                 พะเยา
# 2463326  2440545    2022-02-01  หญิง   8.0   ปี                 พะเยา
# 2463327  2440546    2022-02-01  หญิง  44.0   ปี                 พะเยา
# 2463328  2440547    2022-02-01   ชาย  44.0   ปี                 พะเยา
# ...          ...           ...   ...   ...  ...                   ...
# 2914704  2891923    2022-02-28   ชาย  47.0   ปี              ปทุมธานี
# 2914705  2891924    2022-02-28   ชาย  47.0   ปี             นครสวรรค์
# 2914706  2891925    2022-02-28   ชาย  47.0   ปี             นครสวรรค์
# 2914707  2891926    2022-02-28   ชาย  47.0   ปี             นครสวรรค์
# 2914708  2891927    2022-02-28   ชาย  47.0   ปี             นครสวรรค์
#
#           Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน) ทางราง (คน)  \
# ...

# %%
data2022_3 = data[((data['month'] == 3)) & (data['year'] == 2022)]
data2022_3
# Out:
#              No. announce_date      sex   age Unit province_of_isolation  \
# 2914709  2891928    2022-03-01      ชาย  47.0   ปี            แม่ฮ่องสอน
# 2914710  2891929    2022-03-01     หญิง  47.0   ปี            แม่ฮ่องสอน
# 2914711  2891930    2022-03-01     หญิง  47.0   ปี            แม่ฮ่องสอน
# 2914712  2891931    2022-03-01     หญิง  47.0   ปี            แม่ฮ่องสอน
# 2914713  2891932    2022-03-01     หญิง  47.0   ปี             เชียงใหม่
# ...          ...           ...      ...   ...  ...                   ...
# 3325843  3303062    2022-03-18  ไม่ระบุ  43.0   ปี         กรุงเทพมหานคร
# 3325844  3303063    2022-03-18  ไม่ระบุ  21.0   ปี         กรุงเทพมหานคร
# 3325845  3303064    2022-03-18  ไม่ระบุ  22.0   ปี         กรุงเทพมหานคร
# 3325846  3303065    2022-03-18  ไม่ระบุ  25.0   ปี         กรุงเทพมหานคร
# 3325847  3303066    2022-03-18  ไม่ระบุ  64.0   ปี         กรุงเทพมหานคร
#
#               Province 6 ภูมิภาค (ภูมิศาสตร์)     วันที่ ทางถนน (คน)  \
# ...

# %% [markdown]
# ##save ตารางไปใช้ที่อื่น
# บันทึกลงใน Drive

# %%
data2020.to_csv(os.path.join(path,'data2020.csv'))

# %%
data2021_1.to_csv(os.path.join(path,'data2021_1.csv'))

# %%
data2021_2.to_csv(os.path.join(path,'data2021_2.csv'))

# %%
data2021_3.to_csv(os.path.join(path,'data2021_3.csv'))

# %%
data2021_4.to_csv(os.path.join(path,'data2021_4.csv'))

# %%
data2021_5.to_csv(os.path.join(path,'data2021_5.csv'))

# %%
data2021_6.to_csv(os.path.join(path,'data2021_6.csv'))

# %%
data2022_1.to_csv(os.path.join(path,'data2022_1.csv'))

# %%
data2022_2.to_csv(os.path.join(path,'data2022_2.csv'))

# %%
data2022_3.to_csv(os.path.join(path,'data2022_3.csv'))
